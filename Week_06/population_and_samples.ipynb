# %% [markdown]
# # Population and samples in statistics

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import numpy as np
import random
import statistics
import matplotlib.pyplot as plt
from IPython.display import Image

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_06

# %% [markdown]
# ## fuel consumptions of cars (simulated data)

# %%
# Parameters of distribution
p_mean = 6.5
p_std = 1.8
p_n = 4700000

# Setting a seed to restore the random numbers later
np.random.seed(42)

# Generate (normally distributed) data with mean = 2800 g and standard deviation = 240 g
pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)
print(f'{len(pop):.0f}')
print(f'{np.mean(pop):.4f}')
print(f'{np.std(pop):.4f}')

# Plot histogram based on the data
plt.hist(pop, bins = 50, color='gold')
plt.title('Benzinverbrauch Autos CH (bootstrap sample)', fontsize=10)
plt.xlabel('Verbrauch (L/100km)')
plt.ylabel('Anzahl Autos')

plt.show()
# Out:
# 4700000
# 6.4996
# 1.8002

# %% [markdown]
# ## Single random sample from the population

# %%
# Sample size
sample_size = 200

# Set random seed for reproducibility
random.seed(42)

# Random sample from the population (without replacement)
random_sample = random.sample(list(pop), sample_size)

# Statistics of the sample
print(f'Mean: {statistics.mean(random_sample):.4f}')
print(f'Standard deviation: {statistics.stdev(random_sample):.4f}')

# Plot histogram based on the sample
plt.hist(random_sample, bins = 50, color='deepskyblue')
plt.title(f'Benzinverbrauch Autos CH (single sample with n={sample_size})', fontsize=10)
plt.xlabel('Verbrauch (L/100km)')
plt.ylabel('Anzahl Autos')

plt.show()
# Out:
# Mean: 6.3054
# Standard deviation: 1.6298

# %% [markdown]
# ## Repeated random sampling 'with replacement' (bootstrapping)

# %% [markdown]
# Kleine Sample Size

# %%
def bootstrap(p_mean = 2800, p_std = 240, p_n =25000, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std: Type = int, float
    :param p_n: Type = int, float
    :param num_iter: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    np.random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = np.random.choice(pop, size=sample_size, replace=True)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins=50, color='mediumorchid')
    plt.title('Benzinverbrauch Autos CH (bootstrap sample)', fontsize=10)  # ← Hier ändern!
    plt.xlabel('Verbrauch (L/100km)')  # ← Hier ändern!
    plt.ylabel('Anzahl Samples')  # ← Hier ändern!
    plt.show()

# Function call - Variation 1: Kleine Sample Size
bootstrap(p_mean=6.5, p_std=1.8, num_iter=500, sample_size=50)
# Out:
# 6.5008
# 1.7676

# %% [markdown]
# Mittlere Sample Size

# %%
def bootstrap(p_mean = 2800, p_std = 240, p_n =25000, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std: Type = int, float
    :param p_n: Type = int, float
    :param num_iter: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    np.random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = np.random.choice(pop, size=sample_size, replace=True)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins=50, color='mediumorchid')
    plt.title('Benzinverbrauch Autos CH (bootstrap sample)', fontsize=10)  # ← Hier ändern!
    plt.xlabel('Verbrauch (L/100km)')  # ← Hier ändern!
    plt.ylabel('Anzahl Samples')  # ← Hier ändern!
    plt.show()

# Variation 2: Mittlere Sample Size
bootstrap(p_mean=6.5, p_std=1.8, num_iter=1000, sample_size=200)
# Out:
# 6.5035
# 1.7904

# %% [markdown]
# Sehr viele Iterationen, kleine Sample Size

# %%
def bootstrap(p_mean = 2800, p_std = 240, p_n =25000, num_iter = 5000, sample_size = 200):
    """
    Creates bootstrap sample from a distribution.

    :param p_mean population mean. Type = int, float
    :param p_std: Type = int, float
    :param p_n: Type = int, float
    :param num_iter: number of iterations. Type = int
    :param sample_size: size of single bootstrap sample. Type = int
    :return: plot of bootstrap sample.
    """

    # Setting a seed to restore the random numbers later
    np.random.seed(42)

    # Generate (normally distributed) data
    pop = np.random.normal(loc=p_mean, scale=p_std, size=p_n)

    # Create empty lists to save results of iterations
    sample_mean = []
    sample_std  = []

    # Loop for iterations
    for i in range(num_iter):
        samp = np.random.choice(pop, size=sample_size, replace=True)
        avg = np.mean(samp)
        std = np.std(samp)
        sample_mean.append(avg)
        sample_std.append(std)

    # Print mean and sd of bootsstapped distribution
    print(f'{np.mean(sample_mean):.4f}')
    print(f'{np.mean(sample_std):.4f}')

    # Plot histogram based on the bootstrapped data
    plt.hist(sample_mean, bins=50, color='mediumorchid')
    plt.title('Benzinverbrauch Autos CH (bootstrap sample)', fontsize=10)  # ← Hier ändern!
    plt.xlabel('Verbrauch (L/100km)')  # ← Hier ändern!
    plt.ylabel('Anzahl Samples')  # ← Hier ändern!
    plt.show()

# Variation 4: Sehr viele Iterationen, kleine Sample Size
bootstrap(p_mean=6.5, p_std=1.8, num_iter=10000, sample_size=100)
# Out:
# 6.5013
# 1.7856

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-10-26 18:34:49
# Python Version: 3.11.13
# -----------------------------------
